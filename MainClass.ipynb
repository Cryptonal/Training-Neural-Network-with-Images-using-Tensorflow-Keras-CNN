# %% [markdown]
# <a href="https://colab.research.google.com/github/Cryptonal/Training-Neural-Network-with-Images-using-Tensorflow-Keras-CNN/blob/main/MainClass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

from tensorflow.python.keras.preprocessing import image
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator

# %%
img = image.load_img("/content/profile jpeg.jpg")
plt.imshow(img)

# %%
cv2.imread("/content/profile jpeg.jpg").shape
# Out:
# (549, 680, 3)

# %%
grey_img = np.mean(img, axis=2)
plt.imshow(grey_img)
